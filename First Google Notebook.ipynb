# %% [markdown]
# ##Name

# %% [markdown]
# Christopher Greer

# %% [markdown]
# ##IST Related Interests

# %% [markdown]
# Java programming, Organizational Data, Business use of IT

# %% [markdown]
# ##Future Career

# %% [markdown]
# Something involving data and analytics issues within corporations

# %% [markdown]
# ![alt text](https://github.com/ChrisGreer1/IST210-Spring/blob/master/IMG_3325.JPG)
